# %%
#ejercicio 4

edadjuan = 9
edadalberto = (2/3) * edadjuan
edadana = (4/3) * edadjuan
edadmama = juan + edadalberto + edadana

print("Edad de Juan:", edadjuan)
print("Edad de Alberto:", edadalberto)
print("Edad de Ana:", edadana)
print("Edad de la Mamá:", edadmama)
# Out:
# Edad de Juan: 9
# Edad de Alberto: 6.0
# Edad de Ana: 12.0
# Edad de la Mamá: 31.0

# %%
#ejercicio 5

suma = 0
x = 20
suma = suma + x
y = 40
x = x + y **2
suma = suma + x / y

print("El valor de la suma es:", suma)
# Out:
# El valor de la suma es: 60.5

# %%
#ejercicio 12

horas = 48
valor_hora = 5000
retencion_porcentaje = 0.125

salario_bruto = horas * valor_hora
retencion = salario_bruto * retencion_porcentaje
salario_neto = salario_bruto - retencion

print("Salario Bruto:", salario_bruto)
print("Retención:", retencion)
print("Salario Neto:", salario_neto)
# Out:
# Salario Bruto: 240000
# Retención: 30000.0
# Salario Neto: 210000.0

# %%
#ejercicio 14

numero = 5
cuadrado = numero **2
cubo = numero ** 3

print("Numero:", numero)
print("Cuadrado:", cuadrado)
print("Cubo:", cubo)
# Out:
# Numero: 5
# Cuadrado: 25
# Cubo: 125

# %%
#ejercicio 17

radio = 5
pi = 3.1416

area = pi * radio **2
longitud = 2 * pi * radio

print("Radio:", radio)
print("Area del Circulo:", area)
print("Longitud de circunferencia", longitud)
# Out:
# Radio: 5
# Area del Circulo: 78.53999999999999
# Longitud de circunferencia 31.416
